# %% [markdown]
# ### First Multiple Layered Perceptron (aka. Deep Learning Model)

# %% [markdown]
# <img src="images/single_neuron.png" alt="single_neuron" style="width:60%">

# %% [markdown]
# <img src="images/neural_network.png" alt="nn" style="width:90%">

# %% [markdown]
# <img src="images/deepnetwork.png" alt="dn" style="width:90%">

# %% [markdown]
# <img src="images/backpropa.png" alt="bp" style="width:60%">

# %% [markdown]
# ### Human Brain Neuron System
#
# "<table><tr><td><img src="images/brain.jpeg" alt="brain" style="width:100%"></td><td><img src="images/neurons.jpg" alt="nerons" style="width:50%"></td></tr></table>"

# %%
# !pip install tensorflow -U

# %%
# import tensorflow as tf

# %%
# Data manipulation libraries
import pandas as pd
import numpy as np
import tensorflow as tf

##### Scikit Learn modules needed for Logistic Regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder,MinMaxScaler , StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# Create your first MLP in Keras
# import tf.keras.Sequential as Sequential
# from tf.keras.layers import Dense

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
def prepare_inputData(df):
    # We create the preprocessing pipelines for both numeric and categorical data.
    numeric_features = ['Age', 'Fare']
    numeric_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())])

    categorical_features = ['Embarked', 'Sex', 'Pclass','Parch']
    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
        ('onehot', OneHotEncoder(handle_unknown='ignore'))])

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, numeric_features),
            ('cat', categorical_transformer, categorical_features)])
    
    # preprocess the input variable
    X = preprocessor.fit_transform(df[['Fare','Pclass', 'Name', 'Sex', 'Age','Embarked','Parch']])
    
    #y_oneHot = OneHotEncoder()
    #y = y_oneHot.fit_transform(df["Survived"])
    
    # split data for training and testing
    X_train, X_test, y_train, y_test = train_test_split(X,df["Survived"] ,test_size=0.2,random_state =42)
    
    return X_train, X_test, y_train, y_test

# %%
def train_model(X_train, X_test, y_train, y_test):
    # create model
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(24, input_dim=X_train.shape[1], activation='relu'))
    model.add(tf.keras.layers.Dense(16, activation='relu'))
    model.add(tf.keras.layers.Dense(8, activation='relu'))
    model.add(tf.keras.layers.Dense(4, activation='relu'))
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    #print summary of model architecture
    model.summary()
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    model.fit(X_train, y_train, epochs=50, batch_size=10)
    # evaluate the model
    scores = model.evaluate(X_test, y_test)
    print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    
    return model

# %%
X_train, X_test, y_train, y_test = prepare_inputData(df)
model = train_model(X_train, X_test, y_train, y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 12)                228
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 373
# Trainable params: 373
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 72/72 [==============================] - 2s 3ms/step - loss: 0.6995 - accuracy: 0.4817
# Epoch 2/50
# 72/72 [==============================] - 1s 9ms/step - loss: 0.6490 - accuracy: 0.6882
# Epoch 3/50
# 72/72 [==============================] - 0s 6ms/step - loss: 0.5754 - accuracy: 0.7781: 0s - loss: 0.5837 - accuracy:
# Epoch 4/50
# 72/72 [==============================] - 0s 6ms/step - loss: 0.5089 - accuracy: 0.8118
# Epoch 5/50
# 72/72 [==============================] - 1s 7ms/step - loss: 0.4695 - accuracy: 0.8062
# Epoch 6/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4511 - accuracy: 0.8174
# Epoch 7/50
# 72/72 [==============================] - 0s 4ms/step - loss: 0.4468 - accuracy: 0.7963
# Epoch 8/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4392 - accuracy: 0.8132
# Epoch 9/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4355 - accuracy: 0.8104
# Epoch 10/50
# 72/72 [==============================] - 1s 9ms/step - loss: 0.4298 - accuracy: 0.8160: 0s - loss: 0.4334 - accuracy: 0.
# Epoch 11/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4257 - accuracy: 0.8272
# Epoch 12/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4222 - accuracy: 0.8287
# Epoch 13/50
# 72/72 [==============================] - 0s 4ms/step - loss: 0.4228 - accuracy: 0.8202
# Epoch 14/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4197 - accuracy: 0.8301
# Epoch 15/50
# 72/72 [==============================] - 1s 10ms/step - loss: 0.4169 - accuracy: 0.8287
# Epoch 16/50
# 72/72 [==============================] - 0s 4ms/step - loss: 0.4166 - accuracy: 0.8287
# Epoch 17/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4142 - accuracy: 0.8287
# Epoch 18/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4113 - accuracy: 0.8315
# Epoch 19/50
# 72/72 [==============================] - 0s 4ms/step - loss: 0.4115 - accuracy: 0.8230
# Epoch 20/50
# 72/72 [==============================] - 0s 7ms/step - loss: 0.4094 - accuracy: 0.8258
# Epoch 21/50
# 72/72 [==============================] - 0s 6ms/step - loss: 0.4061 - accuracy: 0.8301
# Epoch 22/50
# 72/72 [==============================] - 0s 6ms/step - loss: 0.4044 - accuracy: 0.8329
# Epoch 23/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4043 - accuracy: 0.8287
# Epoch 24/50
# 72/72 [==============================] - 0s 4ms/step - loss: 0.4028 - accuracy: 0.8315
# Epoch 25/50
# 72/72 [==============================] - 0s 7ms/step - loss: 0.4017 - accuracy: 0.8244
# Epoch 26/50
# 72/72 [==============================] - 0s 4ms/step - loss: 0.3995 - accuracy: 0.8329
# Epoch 27/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3984 - accuracy: 0.8371
# Epoch 28/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3985 - accuracy: 0.8329
# Epoch 29/50
# 72/72 [==============================] - 0s 6ms/step - loss: 0.4002 - accuracy: 0.8272
# Epoch 30/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3977 - accuracy: 0.8301
# Epoch 31/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3955 - accuracy: 0.8357
# Epoch 32/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3965 - accuracy: 0.8287
# Epoch 33/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3952 - accuracy: 0.8343
# Epoch 34/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3922 - accuracy: 0.8371
# Epoch 35/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3909 - accuracy: 0.8371
# Epoch 36/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3889 - accuracy: 0.8385
# Epoch 37/50
# 72/72 [==============================] - 0s 4ms/step - loss: 0.3922 - accuracy: 0.8315
# Epoch 38/50
# 72/72 [==============================] - 0s 4ms/step - loss: 0.3889 - accuracy: 0.8427
# Epoch 39/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3898 - accuracy: 0.8272
# Epoch 40/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3867 - accuracy: 0.8329
# Epoch 41/50
# 72/72 [==============================] - 0s 4ms/step - loss: 0.3850 - accuracy: 0.8385
# Epoch 42/50
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3852 - accuracy: 0.8385
# Epoch 43/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3855 - accuracy: 0.8315
# Epoch 44/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3837 - accuracy: 0.8385
# Epoch 45/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3827 - accuracy: 0.8329
# Epoch 46/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3817 - accuracy: 0.8343
# Epoch 47/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3831 - accuracy: 0.8343
# Epoch 48/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3782 - accuracy: 0.8343
# Epoch 49/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3776 - accuracy: 0.8371
# Epoch 50/50
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3766 - accuracy: 0.8371
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4863 - accuracy: 0.8045
#
# accuracy: 80.45%

# %% [markdown]
# ### For Further Exploration
# - Deep Learning basic concepts simplified : https://www.youtube.com/playlist?list=PLZHQObOWTQDNU6R1_67000Dx_ZCJB-3pi
